# %%
import os
os.getcwd()
# Out:
# '/mnt/Alice/Personal-Development/GS_Quantify_2019'

# %%
import pandas
data = [line.strip() for line in open("train_set.txt", "r").readlines()]
data = [{"Original": line, "LineNumber": line.split('~')[0], "Text": line.split('~')[1].split(']')[-1]} for line in data]

data = pandas.DataFrame(data)
data.head()
# Out:
#   LineNumber                                           Original  \
# 0         L0  L0~gs.api.log.57_13-09-2019_06:59 34703 INFO g...
# 1         L1  L1~gs.compute.log.30_2019-09-12_07:04:00 39946...
# 2         L2  L2~gs.compute.log.77_2019-09-11_10:53:00 94359...
# 3         L3  L3~gs.compute.log.38_2019-09-01_13:31:00 80828...
# 4         L4  L4~gs.api.log.38_Sep 01, 2019_13:20:00 44944 I...
#
#                                                 Text
# 0   HTTP exception thrown: No entry found for any...
# 1   Creating event network-vif-plugged: for instance
# 2   Creating event network-vif-plugged: for instance
# 3   Creating event network-vif-plugged: for instance
# 4   "DELETE /v2/lw7jq0tyfi3n1pxu/servers/details ...

# %%
data.to_csv('out.csv', columns=['LineNumber', 'Text'])

# %%
# !pip install fse
# Out:
# ...
#      |████████████████████████████████| 112kB 637kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 1.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 24.2MB 72kB/s eta 0:00:013    |██████████▍                     | 7.9MB 48kB/s eta 0:05:40
# ...
#      |████████████████████████████████| 32.8MB 184kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 133kB 46kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.0MB 272kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 624kB 236kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 166kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.7MB 69kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 276kB 135kB/s eta 0:00:01
# ...
#   Stored in directory: /home/lorenzo/.cache/pip/wheels/c9/f9/00/f323d92e0091436ce32f54cb7760b8a229469a184f940c2a4d
# ...
#   Stored in directory: /home/lorenzo/.cache/pip/wheels/5f/ea/fb/5b1a947b369724063b2617011f1540c44eb00e28c3d2ca8692
# ...
